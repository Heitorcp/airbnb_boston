# %% [markdown]
# # Airbnb - Data Analysis Project

# %% [markdown]
# ***
# **Author**: Heitor Carvalho
#
# **Email**: heitor.c.pinheiro@usp.br
#
# **Social Media**
#
# * [LinkedIn](https://www.linkedin.com/in/heitor-carvalho-pinheiro-4b58851b7/)
# * [Medium Blog](https://medium.com/@heitor-c-pinheiro)
#
# **License**: Creative Commons
#
# [**Medium Post about this analysis**]()
# ***

# %% [markdown]
# ## Index
#
# * [1. Introduction](#1)
# * [2. Data Dictionary](#2)
# * [3. Data Pre-Processing](#3)
# * [4. EDA](#4)
# * [5. Conclusion](#5)
#
#
# ***

# %% [markdown]
# # Introduction <a class="anchor" id="1"></a>

# %% [markdown]
# Last year, I had the opportunity to spend a few days in Boston and I wish I could have stayed longer. According to [WalkScore](https://www.walkscore.com/cities-and-neighborhoods/#:~:text=All%20Cities%20%20%20%20City%20%20,%20%2048.6%20%2050%20more%20rows%20), a nice website that ranks the Transit, Bike, and Walk Score from a lot of different
# cities in the world, Boston ranks in the 4th place when it comes to most "walking-friendly" cities. No wonder why it is nicknamed the "walking city".
#
# In this article, I analyzed the Boston Airbnb data from 12/17/21 as a way to help you choose the best room based on your own needs. **I want to make a quick disclaimer though, saying that since the data is not from 2022
# some of its rooms and therefore metrics will not be up to date**, but even so, I hope it will come in handy the next time you'll be planning to visit Boston.

# %% [markdown]
# # Data Dictionary <a class="anchor" id="2"></a>

# %% [markdown]
# |    | id                                           | Airbnb's unique identifier for the listing                                                                                                                                                                                                                                                                                                                                                      |
# |---:|:---------------------------------------------|:------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  0 | listing_url                                  | nan                                                                                                                                                                                                                                                                                                                                                                                             |
# |  1 | scrape_id                                    | Inside Airbnb "Scrape" this was part of                                                                                                                                                                                                                                                                                                                                                         |
# |  2 | last_scraped                                 | UTC. The date and time this listing was "scraped".                                                                                                                                                                                                                                                                                                                                              |
# |  3 | name                                         | Name of the listing                                                                                                                                                                                                                                                                                                                                                                             |
# |  4 | description                                  | Detailed description of the listing                                                                                                                                                                                                                                                                                                                                                             |
# |  5 | neighborhood_overview                        | Host's description of the neighbourhood                                                                                                                                                                                                                                                                                                                                                         |
# |  6 | picture_url                                  | URL to the Airbnb hosted regular sized image for the listing                                                                                                                                                                                                                                                                                                                                    |
# |  7 | host_id                                      | Airbnb's unique identifier for the host/user                                                                                                                                                                                                                                                                                                                                                    |
# |  8 | host_url                                     | The Airbnb page for the host                                                                                                                                                                                                                                                                                                                                                                    |
# |  9 | host_name                                    | Name of the host. Usually just the first name(s).                                                                                                                                                                                                                                                                                                                                               |
# | 10 | host_since                                   | The date the host/user was created. For hosts that are Airbnb guests this could be the date they registered as a guest.                                                                                                                                                                                                                                                                         |
# | 11 | host_location                                | The host's self reported location                                                                                                                                                                                                                                                                                                                                                               |
# | 12 | host_about                                   | Description about the host                                                                                                                                                                                                                                                                                                                                                                      |
# | 13 | host_response_time                           | nan                                                                                                                                                                                                                                                                                                                                                                                             |
# | 14 | host_response_rate                           | nan                                                                                                                                                                                                                                                                                                                                                                                             |
# | 15 | host_acceptance_rate                         | That rate at which a host accepts booking requests.                                                                                                                                                                                                                                                                                                                                             |
# | 16 | host_is_superhost                            | nan                                                                                                                                                                                                                                                                                                                                                                                             |
# | 17 | host_thumbnail_url                           | nan                                                                                                                                                                                                                                                                                                                                                                                             |
# | 18 | host_picture_url                             | nan                                                                                                                                                                                                                                                                                                                                                                                             |
# | 19 | host_neighbourhood                           | nan                                                                                                                                                                                                                                                                                                                                                                                             |
# | 20 | host_listings_count                          | The number of listings the host has (per Airbnb calculations)                                                                                                                                                                                                                                                                                                                                   |
# | 21 | host_total_listings_count                    | The number of listings the host has (per Airbnb calculations)                                                                                                                                                                                                                                                                                                                                   |
# | 22 | host_verifications                           | nan                                                                                                                                                                                                                                                                                                                                                                                             |
# | 23 | host_has_profile_pic                         | nan                                                                                                                                                                                                                                                                                                                                                                                             |
# | 24 | host_identity_verified                       | nan                                                                                                                                                                                                                                                                                                                                                                                             |
# | 25 | neighbourhood                                | nan                                                                                                                                                                                                                                                                                                                                                                                             |
# | 26 | neighbourhood_cleansed                       | The neighbourhood as geocoded using the latitude and longitude against neighborhoods as defined by open or public digital shapefiles.                                                                                                                                                                                                                                                           |
# | 27 | neighbourhood_group_cleansed                 | The neighbourhood group as geocoded using the latitude and longitude against neighborhoods as defined by open or public digital shapefiles.                                                                                                                                                                                                                                                     |
# | 28 | latitude                                     | Uses the World Geodetic System (WGS84) projection for latitude and longitude.                                                                                                                                                                                                                                                                                                                   |
# | 29 | longitude                                    | Uses the World Geodetic System (WGS84) projection for latitude and longitude.                                                                                                                                                                                                                                                                                                                   |
# | 30 | property_type                                | Self selected property type. Hotels and Bed and Breakfasts are described as such by their hosts in this field                                                                                                                                                                                                                                                                                   |
# | 31 | room_type                                    | [Entire home/apt|Private room|Shared room|Hotel]                                                                                                                                                                                                                                                                                                                                                |
# |    |                                              |                                                                                                                                                                                                                                                                                                                                                                                                 |
# |    |                                              | All homes are grouped into the following three room types:                                                                                                                                                                                                                                                                                                                                      |
# |    |                                              |                                                                                                                                                                                                                                                                                                                                                                                                 |
# |    |                                              | Entire place                                                                                                                                                                                                                                                                                                                                                                                    |
# |    |                                              | Private room                                                                                                                                                                                                                                                                                                                                                                                    |
# |    |                                              | Shared room                                                                                                                                                                                                                                                                                                                                                                                     |
# |    |                                              | Entire place                                                                                                                                                                                                                                                                                                                                                                                    |
# |    |                                              | Entire places are best if you're seeking a home away from home. With an entire place, you'll have the whole space to yourself. This usually includes a bedroom, a bathroom, a kitchen, and a separate, dedicated entrance. Hosts should note in the description if they'll be on the property or not (ex: "Host occupies first floor of the home"), and provide further details on the listing. |
# |    |                                              |                                                                                                                                                                                                                                                                                                                                                                                                 |
# |    |                                              | Private rooms                                                                                                                                                                                                                                                                                                                                                                                   |
# |    |                                              | Private rooms are great for when you prefer a little privacy, and still value a local connection. When you book a private room, you'll have your own private room for sleeping and may share some spaces with others. You might need to walk through indoor spaces that another host or guest may occupy to get to your room.                                                                   |
# |    |                                              |                                                                                                                                                                                                                                                                                                                                                                                                 |
# |    |                                              | Shared rooms                                                                                                                                                                                                                                                                                                                                                                                    |
# |    |                                              | Shared rooms are for when you don't mind sharing a space with others. When you book a shared room, you'll be sleeping in a space that is shared with others and share the entire space with other people. Shared rooms are popular among flexible travelers looking for new friends and budget-friendly stays.                                                                                  |
# | 32 | accommodates                                 | The maximum capacity of the listing                                                                                                                                                                                                                                                                                                                                                             |
# | 33 | bathrooms                                    | The number of bathrooms in the listing                                                                                                                                                                                                                                                                                                                                                          |
# | 34 | bathrooms_text                               | The number of bathrooms in the listing.                                                                                                                                                                                                                                                                                                                                                         |
# |    |                                              | On the Airbnb web-site, the bathrooms field has evolved from a number to a textual description. For older scrapes, bathrooms is used.                                                                                                                                                                                                                                                           |
# | 35 | bedrooms                                     | The number of bedrooms                                                                                                                                                                                                                                                                                                                                                                          |
# | 36 | beds                                         | The number of bed(s)                                                                                                                                                                                                                                                                                                                                                                            |
# | 37 | amenities                                    | nan                                                                                                                                                                                                                                                                                                                                                                                             |
# | 38 | price                                        | daily price in local currency                                                                                                                                                                                                                                                                                                                                                                   |
# | 39 | minimum_nights                               | minimum number of night stay for the listing (calendar rules may be different)                                                                                                                                                                                                                                                                                                                  |
# | 40 | maximum_nights                               | maximum number of night stay for the listing (calendar rules may be different)                                                                                                                                                                                                                                                                                                                  |
# | 41 | minimum_minimum_nights                       | the smallest minimum_night value from the calender (looking 365 nights in the future)                                                                                                                                                                                                                                                                                                           |
# | 42 | maximum_minimum_nights                       | the largest minimum_night value from the calender (looking 365 nights in the future)                                                                                                                                                                                                                                                                                                            |
# | 43 | minimum_maximum_nights                       | the smallest maximum_night value from the calender (looking 365 nights in the future)                                                                                                                                                                                                                                                                                                           |
# | 44 | maximum_maximum_nights                       | the largest maximum_night value from the calender (looking 365 nights in the future)                                                                                                                                                                                                                                                                                                            |
# | 45 | minimum_nights_avg_ntm                       | the average minimum_night value from the calender (looking 365 nights in the future)                                                                                                                                                                                                                                                                                                            |
# | 46 | maximum_nights_avg_ntm                       | the average maximum_night value from the calender (looking 365 nights in the future)                                                                                                                                                                                                                                                                                                            |
# | 47 | calendar_updated                             | nan                                                                                                                                                                                                                                                                                                                                                                                             |
# | 48 | has_availability                             | [t=true; f=false]                                                                                                                                                                                                                                                                                                                                                                               |
# | 49 | availability_30                              | avaliability_x. The availability of the listing x days in the future as determined by the calendar. Note a listing may not be available because it has been booked by a guest or blocked by the host.                                                                                                                                                                                           |
# | 50 | availability_60                              | avaliability_x. The availability of the listing x days in the future as determined by the calendar. Note a listing may not be available because it has been booked by a guest or blocked by the host.                                                                                                                                                                                           |
# | 51 | availability_90                              | avaliability_x. The availability of the listing x days in the future as determined by the calendar. Note a listing may not be available because it has been booked by a guest or blocked by the host.                                                                                                                                                                                           |
# | 52 | availability_365                             | avaliability_x. The availability of the listing x days in the future as determined by the calendar. Note a listing may not be available because it has been booked by a guest or blocked by the host.                                                                                                                                                                                           |
# | 53 | calendar_last_scraped                        | nan                                                                                                                                                                                                                                                                                                                                                                                             |
# | 54 | number_of_reviews                            | The number of reviews the listing has                                                                                                                                                                                                                                                                                                                                                           |
# | 55 | number_of_reviews_ltm                        | The number of reviews the listing has (in the last 12 months)                                                                                                                                                                                                                                                                                                                                   |
# | 56 | number_of_reviews_l30d                       | The number of reviews the listing has (in the last 30 days)                                                                                                                                                                                                                                                                                                                                     |
# | 57 | first_review                                 | The date of the first/oldest review                                                                                                                                                                                                                                                                                                                                                             |
# | 58 | last_review                                  | The date of the last/newest review                                                                                                                                                                                                                                                                                                                                                              |
# | 59 | review_scores_rating                         | nan                                                                                                                                                                                                                                                                                                                                                                                             |
# | 60 | review_scores_accuracy                       | nan                                                                                                                                                                                                                                                                                                                                                                                             |
# | 61 | review_scores_cleanliness                    | nan                                                                                                                                                                                                                                                                                                                                                                                             |
# | 62 | review_scores_checkin                        | nan                                                                                                                                                                                                                                                                                                                                                                                             |
# | 63 | review_scores_communication                  | nan                                                                                                                                                                                                                                                                                                                                                                                             |
# | 64 | review_scores_location                       | nan                                                                                                                                                                                                                                                                                                                                                                                             |
# | 65 | review_scores_value                          | nan                                                                                                                                                                                                                                                                                                                                                                                             |
# | 66 | license                                      | The licence/permit/registration number                                                                                                                                                                                                                                                                                                                                                          |
# | 67 | instant_bookable                             | [t=true; f=false]. Whether the guest can automatically book the listing without the host requiring to accept their booking request. An indicator of a commercial listing.                                                                                                                                                                                                                       |
# | 68 | calculated_host_listings_count               | The number of listings the host has in the current scrape, in the city/region geography.                                                                                                                                                                                                                                                                                                        |
# | 69 | calculated_host_listings_count_entire_homes  | The number of Entire home/apt listings the host has in the current scrape, in the city/region geography                                                                                                                                                                                                                                                                                         |
# | 70 | calculated_host_listings_count_private_rooms | The number of Private room listings the host has in the current scrape, in the city/region geography                                                                                                                                                                                                                                                                                            |
# | 71 | calculated_host_listings_count_shared_rooms  | The number of Shared room listings the host has in the current scrape, in the city/region geography                                                                                                                                                                                                                                                                                             |
# | 72 | reviews_per_month                            | The number of reviews the listing has over the lifetime of the listing                                                                                                                                                                                                                                                                                                                          |

# %% [markdown]
# This data was scraped on 12/17/21
# ***

# %% [markdown]
# ## Importing all the libraries

# %%
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt, mpld3
import seaborn as sns
import plotly.express as px
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# # Data Pre-Processing <a class="anchor" id="3"></a>

# %%
#reading the dataframe
#df is a clean version of the original dataset (I've cleaned it using Excel)
df = pd.read_csv(r"C:\Users\heito\OneDrive\Documentos\Estudos\dsnp\3.0\modulo01\Airbnb project\data\listings.csv\listings.csv")

#the original dataset
df_raw = pd.read_csv(r"C:\Users\heito\OneDrive\Documentos\Estudos\dsnp\3.0\modulo01\Airbnb project\data\listings.csv\listings_raw.csv")

print("Cleaned Dataset dimension", df.shape)
print("Original Dataset dimension", df_raw.shape)
# Out:
# Cleaned Dataset dimension (3349, 54)
# Original Dataset dimension (3349, 74)

# %%
df.drop(labels=['host_name','host_about'], axis=1, inplace=True)

# %% [markdown]
# ##### Null values

# %% [markdown]
# Values to fill in with the mean (for future ML models)
#
# * host_response_time
# * host_response_rate
# * host_acceptance_rate
# * bedrooms
# * bathroom_text
# * beds

# %%
df_raw.isnull().sum()
# Out:
# id                                                0
# listing_url                                       0
# scrape_id                                         0
# last_scraped                                      0
# name                                              0
#                                                ...
# calculated_host_listings_count                    0
# calculated_host_listings_count_entire_homes       0
# calculated_host_listings_count_private_rooms      0
# calculated_host_listings_count_shared_rooms       0
# reviews_per_month                               999
# Length: 74, dtype: int64

# %% [markdown]
# We have a lot of null values on the collumns. But, since I will only focus on a Exploratory Data Analysis in this notebook, I am going to choose to do the cleaning throughout the analysis as the need arises. That being said I will stick to the original dataset in this notebook.

# %% [markdown]
# ## Introduction <a class="anchor" id="2"></a>

# %% [markdown]
# First things first, like learning a new song by ear, before going right away to the instrument you have to listen to it several times. You need to understand first, what you need to do, then you can begin to figure out its first notes and chords. The same goes with Data Science, before diving into the analysis itself or even the Machine Learning model, you have to ask yourself: **What questions do I want to answer?**

# %% [markdown]
# So, here are some question we can ask to gain some intuition on the dataset, I won't answer all of them in this analysis. It's just for have some idea of possible questions
#
# * [X] ~~*How many properties are available in Boston*~~ [2022-02-17]
# * [X] ~~*What is the number of hosts in Boston*~~ [2022-02-17]
# * [X] ~~*Room_type availables*~~ [2022-02-16]
# * [X] ~~*What are the most popular neighbourhoods*~~ [2022-02-18]
# * [X] ~~*What is the distribution of the number of reviews*~~ [2022-02-26]
# * [ ] What is the overall_satisfaction by each rating?
# * [X] ~~*Describe the dataset using describe*~~ [2022-02-24]
# * [ ] What is the satisfaction rating per bedroom number?
# * [ ] What ammenities are most responsible for a high rating? (Correlation)
# * [ ] What is the satisfaction rate per price range?
# * [X] ~~*What is the most frequent accomodation value?*~~ [2022-02-24]
# * [X] ~~*On which price most of the properties are available?*~~ [2022-02-26]
# * [X] ~~*What is the proportion of each bedrooms values?*~~ [2022-02-16]
# * [X] ~~*(Remove, if its reasonable the values in which bedroom is equal to 0)*~~ [2022-02-24]

# %% [markdown]
# Even tough, we might have a lot of questions to be answered we can never forget the main reason that someone looks for a room in *Airbnb*: Best value (cost-benefit) possible! (idk, at least for me :) ) or other reasons such as luxury, neighbourhood etc.
# In this analysis I will focus solely on the price and rating.

# %% [markdown]
# # Exploratory Data Analysis (EDA) <a class="anchor" id="4"></a>

# %% [markdown]
# ## Number of Properties at 12/17/21

# %%
#lets check if there is any duplicated values
df_raw.duplicated(subset='id').value_counts()
# Out:
# False    3349
# dtype: int64

# %% [markdown]
# On 12/17/21 there were 3349 apartments available to rent on Airbnb in Boston. Surely, you won't look at all of them. :)

# %% [markdown]
# ## Number of hosts in Boston

# %%
df_raw.drop_duplicates(subset='host_id').shape
# Out:
# (1205, 74)

# %% [markdown]
# There are 1205 different host in our dataset

# %% [markdown]
# ### Super Hosts

# %%
df_raw.host_is_superhost.value_counts(normalize=True)
# Out:
# f    0.666336
# t    0.333664
# Name: host_is_superhost, dtype: float64

# %% [markdown]
# #### What is a Super Host?

# %% [markdown]
# So, 33% of all hosts are superhosts in Boston. If you are wondering what makes a host a Super Host on Airbnb, it's pretty straightforward. First, superhosts have a 4.8 or higher average overall rating, so it means you'll have an outstanding hospitality. They have completed at least 10 stays in the past year, so you can expect experienced hosts. They also have <1% cancellation rate and last but no least, they responde 90% of messages within 24h.

# %%
#defining colors
GRAY1, GRAY2, GRAY3 = '#231F20', '#414040', '#555655'
GRAY4, GRAY5, GRAY6 = '#646369', '#76787B', '#828282'
GRAY7, GRAY8, GRAY9 = '#929497', '#A6A6A5', '#BFBEBE'
BLUE1, BLUE2, BLUE3, BLUE4 = '#174A7E', '#4A81BF', '#94B2D7', '#94AFC5'
RED1, RED2 = '#C3514E', '#E6BAB7'
GREEN1, GREEN2 = '#0C8040', '#9ABB59'
ORANGE1 = '#F79747'

# %%
#configure plot font family to arial
# configure plot font family to Arial
plt.rcParams['font.family'] = 'Arial'
# configure mathtext bold and italic font family to Arial
matplotlib.rcParams['mathtext.fontset'] = 'custom'
matplotlib.rcParams['mathtext.bf'] = 'Arial:bold'
matplotlib.rcParams['mathtext.it'] = 'Arial:italic'

# %%
# create new figure
plt.figure(figsize=(7.45, 4.9), # width, height in inches
           dpi=110)             # resolution of the figure
plt.yticks([])
plt.xticks([])


# remove chart border
for spine in plt.gca().spines.values():
    spine.set_visible(False)


# change the appearance of ticks, tick labels, and gridlines 
plt.tick_params(bottom='off', left='off', labelleft='off', labelbottom='off')

# title the plot
plt.text(-0.15, 1.03,
         'Airbnb Superhosts in Boston'+' '*27,
         fontsize=26,
         color='white',
         # put a rectangular box around the text to set a background color
         bbox={'facecolor': GRAY7, 'pad': 12, 'edgecolor': 'none'})


# footnote with the data source
plt.text(-0.15, 0.04,
         'Based on the data scraped on 12/17/2021 from Inside Airbnb',
         fontsize=10.5,
         color=GRAY3)

# add note to the plot
plt.text(-0.15, 0.81,
         'In 2021 only',
         fontsize=19,
         color=BLUE2)

plt.text(-0.15, 0.41,
         '$\\bf{33\%}$', # use mathtext \\bf for bold text
         fontsize=122,
         color=BLUE2)

plt.text(-0.15, 0.25,
         # use mathtext \\bf for bold text
         '$\\bf{of\ hosts\ were\ SuperHosts\ on\ the\ Boston\ Area}$',
         fontsize=19,
         color=BLUE2)



# plt.savefig("superhosts_boston.png", dpi=150)

plt.show()

# %% [markdown]
# It turns out that from 3349 different apartments to pick in Boston, there are 1205 hosts for you to consider. Definitely you won't get the change to meet all of them.

# %% [markdown]
# That being said, and knowing that only 1/3 of hosts are superhosts, we can take a closer look at those apartments.
# I will create a subset of the data with only superhosts in it.

# %%
#df with only superhosts
super_host_df = df_raw[df_raw.host_is_superhost == 't']

#deleting the rows wich price equal 0 (it's gonna help us later)
index = super_host_df[super_host_df['price'] == 0.0].index
super_host_df.price.drop(index, inplace=True)
super_host_df.set_index('id', inplace=True)
# Out:
# C:\Users\heito\AppData\Local\Temp\ipykernel_24120\355169406.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super_host_df.price.drop(index, inplace=True)

# %%
super_host_df.price.nsmallest()
# Out:
# id
# 46232976     0.0
# 45828592    10.0
# 51816556    23.0
# 52532097    24.0
# 29711943    25.0
# Name: price, dtype: float64

# %% [markdown]
# ## Distribution of Room types

# %%
df_raw.room_type.value_counts(normalize=True)
# Out:
# Entire home/apt    0.627650
# Private room       0.361302
# Hotel room         0.007465
# Shared room        0.003583
# Name: room_type, dtype: float64

# %% [markdown]
# Entire homes/apts and Private Rooms accounts for 98% of our data. So, it will not consider the Hotel Rooms and the Shared Rooms in our Analysis.

# %% [markdown]
# ## Distribution of the Number of Bedrooms

# %%
df_raw.bedrooms.value_counts(normalize=True).to_frame()
# Out:
#       bedrooms
# 1.0   0.700208
# 2.0   0.189105
# 3.0   0.067314
# 4.0   0.032616
# 5.0   0.007981
# 6.0   0.001735
# 7.0   0.000694
# 13.0  0.000347

# %% [markdown]
# ## Distribution of the number of bathrooms

# %%
df_raw.bathrooms_text.value_counts(normalize=True)
# Out:
# 1 bath               0.506878
# 1 shared bath        0.160885
# 2 baths              0.103768
# 2 shared baths       0.063995
# 1 private bath       0.051435
# 1.5 baths            0.033792
# 1.5 shared baths     0.029605
# 2.5 baths            0.013756
# 3 baths              0.009868
# 2.5 shared baths     0.005682
# 5 shared baths       0.004187
# 6 shared baths       0.004187
# 3.5 baths            0.003888
# 3 shared baths       0.002093
# 0 shared baths       0.001495
# 5 baths              0.000897
# 4 shared baths       0.000897
# 4.5 baths            0.000598
# Private half-bath    0.000299
# 0 baths              0.000299
# Shared half-bath     0.000299
# 6 baths              0.000299
# 3.5 shared baths     0.000299
# Half-bath            0.000299
# 4 baths              0.000299
# Name: bathrooms_text, dtype: float64

# %% [markdown]
# ## The most popular neighbourhoods

# %%
df_raw.neighbourhood.value_counts()
# Out:
# Boston, Massachusetts, United States                    2089
# Dorchester , Massachusetts, United States                 13
# East Boston, Massachusetts, United States                  7
# Jamaica Plain, Massachusetts, United States                6
# Charlestown, Massachusetts, United States                  5
# Dorchester, Massachusetts, United States                   4
# BOSTON, Massachusetts, United States                       4
# Boston , Massachusetts, United States                      3
# Cambridge, Massachusetts, United States                    3
# Roslindale, Massachusetts, United States                   3
# Brighton, Massachusetts, United States                     2
# 波士顿, Massachusetts, United States                          1
# Allston, Massachusetts, United States                      1
# Boston/Charlestown , Massachusetts, United States          1
# Dorchster , Massachusetts, United States                   1
# ...

# %%
df_raw.neighbourhood.isnull().sum()/df_raw.neighbourhood.shape[0]
# Out:
# 0.35592714243057627

# %% [markdown]
# Well, we don't have the information about 35.6% of apartments neigbourhoods.

# %% [markdown]
# Cleaning the neighbourhoods a little

# %%
df_raw.neighbourhood = df_raw.neighbourhood.str.lower()

# %%
df_raw.neighbourhood = df_raw.neighbourhood.str.replace(', massachusetts, united states','')
df_raw.neighbourhood.replace({'boston ':'boston', '波士顿':'boston','dorchester ': 'dorchester','hyde park ':'hyde park', 'dorschester ':'dorchester', 'boston(jamaica plain)':'jamaica plain','dorchster ':'dorchester', 'jamaica plain ':'jamaica plain', 'jamaica plain (boston)':'jamaica plain', 'jamaica plain, boston':'jamaica plain', 'boston/charlestown ':'charlestown', 'bostonallston, ma, united states':'allston', 'boston, ':'boston', 'boston (jamaica plain)':'jamaica plan', 'boston, allston, ma, united states':'allston', 'jamaica plan':'jamaica plain' }, inplace=True)

# %%
df_raw.neighbourhood.value_counts()
# Out:
# boston              2098
# dorchester            18
# jamaica plain          9
# east boston            7
# charlestown            6
# cambridge              3
# roslindale             3
# allston                2
# brighton               2
# hyde park              2
# jamaica plan           1
# dedham                 1
# brookline              1
# roxbury crossing       1
# chestnut hill          1
# somerville             1
# milton                 1
# Name: neighbourhood, dtype: int64

# %% [markdown]
# Well, it seems unreasonable to analyse other neighbourhoods but Boston given the low data number

# %% [markdown]
# ## Correlogram

# %% [markdown]
# A correlogram is a type of plot which shows us any sort of relationship between two variables. These relationships are pretty easy, they evaluate if there is any linear dependence between these variables.
# So a question that we might ask is: as the number of bedrooms increase so does the room price?
# If so, then there is going to be some dependence between these two variables and so some correlation.
# Let's check it for all numerical variables in our dataset.

# %%
plt.figure(figsize=(12,10), dpi= 80)
sns.heatmap(df_raw.corr(), xticklabels=df_raw.corr().columns, yticklabels=df_raw.corr().columns, cmap='RdYlGn', center=0, annot=False)

plt.show()

# %% [markdown]
# The price seems to have a higher correlation with the the variables "accommodates", "bedrooms" and "beds", but none these values seems to be high enough to be considered (in this case I am considering high correlations as 0.8 and above)

# %% [markdown]
# ## Number of Reviews

# %%
df_raw.number_of_reviews[df_raw.number_of_reviews != 0].describe().to_frame()
# Out:
#        number_of_reviews
# count        2350.000000
# mean           54.600426
# std            84.518303
# min             1.000000
# 25%             5.000000
# 50%            21.000000
# 75%            64.000000
# max           678.000000

# %% [markdown]
# The table above tells us that from all reviews, the minimum value is 1 (obvious :)), the maximum value is 678 - which we don't know yet if it's an error or not, and it also tells us that half of the apartments that have any review have up to 21 reviews while 75% of them have at most 64 reviews.

# %%
#number of apartments that have 0 reviews
no_reviews = len(df_raw.number_of_reviews[df_raw.number_of_reviews == 0])

#number of apartments that have at least 1 review
num_reviews = len(df_raw.number_of_reviews[df_raw.number_of_reviews != 0])

print("Number of apartments with no reviews:", no_reviews)
print("Number of apartments that have at least one review:", num_reviews)
# Out:
# Number of apartments with no reviews: 999
# Number of apartments that have at least one review: 2350

# %%
pd.cut(df_raw.number_of_reviews[df_raw.number_of_reviews >= 1], precision=0 , bins=np.linspace(0,680, 11)).value_counts(normalize=True).round(4)
pd.qcut(df_raw.number_of_reviews[df_raw.number_of_reviews >= 1], q=4).value_counts()
# Out:
# (0.999, 5.0]     636
# (64.0, 678.0]    585
# (21.0, 64.0]     578
# (5.0, 21.0]      551
# Name: number_of_reviews, dtype: int64

# %% [markdown]
# Apartments with reviews up to 418, accounts for basically 99% of our dataset. That being said our analysis should focus and split the number of reviews in 10 bins. And, for the higher values we can a specific analysis on them, given that they account for 24 apartments

# %%
arr = df_raw.number_of_reviews[df_raw.number_of_reviews != 0]

# %%
#setting seaborn style
sns.set_style('white')

fig = plt.figure(figsize=(12,6))
ax = sns.histplot(data=df_raw, x=df_raw.number_of_reviews[df_raw.number_of_reviews != 0], stat='percent', bins=10)
ax.bar_label(ax.containers[-1], fmt="%.0f", label_type='edge', padding=2.)

#array with bins edges that goes in the xticks
bins = np.histogram_bin_edges(df_raw.number_of_reviews[df_raw.number_of_reviews != 0], bins=10)
#rounding the bins
ax.set_xticks(bins.round(0))
ax.set_yticks([])

plt.title("Distribution of the Number of Reviews", fontsize=20)
plt.xlabel("Number of Reviews")
plt.show()

# %% [markdown]
# ##### A more advanced histogram

# %%
from matplotlib.patches import Rectangle

# Colours for different percentiles
perc_25_colour = 'gold'
perc_50_colour = 'mediumaquamarine'
perc_75_colour = 'deepskyblue'
perc_95_colour = 'peachpuff'


fig, ax = plt.subplots(figsize=(8,8))


counts, bins, patches = ax.hist(df_raw.number_of_reviews[df_raw.number_of_reviews != 0], facecolor=perc_50_colour, edgecolor='gray')

# Change the colors of bars at the edges

#defining the percentiles
twentyfifth, seventyfifth, ninetyfifth = np.percentile(df_raw.number_of_reviews[df_raw.number_of_reviews != 0], [25, 75, 95])
for patch, leftside, rightside in zip(patches, bins[:-1], bins[1:]):
    if rightside < twentyfifth:
        patch.set_facecolor(perc_25_colour)
    elif leftside > ninetyfifth:
        patch.set_facecolor(perc_95_colour)
    elif leftside > seventyfifth:
        patch.set_facecolor(perc_75_colour)


#Set ticks at the edges of the bins
ax.set_xticks(bins.round(0))
plt.xticks(rotation=70)

# Set the graph title and axes titles
plt.title('Distribution of the Number of Reviews', fontsize=20)
plt.ylabel('Count', fontsize=15)
plt.xlabel('Number of Reviews', fontsize=15)


# Change the colors of bars at the edges
twentyfifth, seventyfifth, ninetyfifth = np.percentile(df_raw.number_of_reviews[df_raw.number_of_reviews != 0], [25, 75, 95])
for patch, leftside, rightside in zip(patches, bins[:-1], bins[1:]):
    if rightside < twentyfifth:
        patch.set_facecolor(perc_25_colour)
    elif leftside > ninetyfifth:
        patch.set_facecolor(perc_95_colour)
    elif leftside > seventyfifth:
        patch.set_facecolor(perc_75_colour)

# Calculate bar centre to display the count of data points and %
bin_x_centers = 0.5 * np.diff(bins) + bins[:-1]
bin_y_centers = ax.get_yticks()[1] * 0.25

# Display the the count of data points and % for each bar in histogram
for i in range(len(bins)-1):
    bin_label = "{0:,}".format(counts[i]) + "  ({0:,.2f}%)".format((counts[i]/counts.sum())*100)
    plt.text(bin_x_centers[i], bin_y_centers, bin_label, rotation=90, rotation_mode='anchor')

# Annotation for bar values
ax.annotate('Each bar shows count and percentage of total',
            xy=(.85,.30), xycoords='figure fraction',
            horizontalalignment='center', verticalalignment='bottom',
            fontsize=10, bbox=dict(boxstyle="round", fc="white"),
            rotation=-90)

#create legend
handles = [Rectangle((0,0),1,1,color=c,ec="k") for c in [perc_25_colour, perc_50_colour, perc_75_colour, perc_95_colour]]
labels= ["0-25 Percentile","25-50 Percentile", "50-75 Percentile", ">95 Percentile"]
plt.legend(handles, labels, bbox_to_anchor=(0.5, 0., 0.80, 0.99))

# Display the graph
plt.show()

# %% [markdown]
# That histogram is telling us that 76% of all rooms (the bar in green) that have at least 1 review have received no more than 69 reviews. Almost 22% of rooms in our dataset have received between 69 and 272 reviews - which makes them inside of the 50th - 75th percentile. And only 2% of rooms have received a number of reviews between 272 and 678. (The 95th and above percentile in beige).
#
# You can check this plot in the following Medium post by Anandakumar Varatharajah:
# https://towardsdatascience.com/advanced-histogram-using-python-bceae288e715
#
# I going to leave a barchart framework below that you can adapt to your needs

# %%
# #framework to create bars with annotation on top of it
# labels = ['G1', 'G2', 'G3']
# men_means = [20,34,42]
# women_means = [25,32,34]

# x = np.arange(len(labels))
# width = 0.35 #width of the bars

# #creating the plot
# fig, ax = plt.subplots()
# rects1 = ax.bar(x - width/2, men_means, width, label = 'Men')
# rects2 = ax.bar(x + width/2, women_means, width, label = 'Women')




# #create some custom labels and titles
# ax.set_ylabel('Scores')
# ax.set_title('Scores by Group and Gender')
# ax.set_xticks(x, labels)
# ax.legend()

# #annotating on top of the bars
# ax.bar_label(rects1, padding=2)
# ax.bar_label(rects2, padding=2)

# fig.tight_layout()

# plt.show()

# %% [markdown]
# ## Review Score Rating

# %%
df_raw.review_scores_rating
# Out:
# 0       4.95
# 1       4.78
# 2       4.80
# 3       4.64
# 4       4.78
#         ...
# 3344     NaN
# 3345     NaN
# 3346     NaN
# 3347     NaN
# 3348     NaN
# Name: review_scores_rating, Length: 3349, dtype: float64

# %% [markdown]
# ### Mean of Review Score Rating

# %%
np.nanmean(df_raw.review_scores_rating).round(1)
# Out:
# 4.7

# %% [markdown]
# The mean score rating for the rooms in Boston is 4.7 stars.

# %% [markdown]
# We can also divide the data into quantiles based on the score rating

# %%
pd.qcut(df_raw.review_scores_rating, q=4).value_counts()
# Out:
# (4.58, 4.8]       604
# (-0.001, 4.58]    603
# (4.8, 4.95]       574
# (4.95, 5.0]       569
# Name: review_scores_rating, dtype: int64

# %% [markdown]
# So the data can be divided into the following: 25% of the rooms have between 0 and 4.58 reviews. The next quantile has between 4.58 and 4.8 reviews. The third quantile has between 4.8 and 4.95 reviews and the last quantile has more than 4.95 reviews.

# %% [markdown]
# Knowing that the mean rate score is 4.7 it does not make much sense to divide the rating into equal-sized quantiles but rather into more "understandable" bins for the public, ranging from 1 to 5

# %%
#subset with not null review_scores_rating values
ratings = df_raw.review_scores_rating[df_raw.review_scores_rating.notna()]
pd.cut(ratings, bins=5).value_counts(normalize=True)
# Out:
# (4.0, 5.0]       0.929362
# (3.0, 4.0]       0.050638
# (2.0, 3.0]       0.011064
# (-0.005, 1.0]    0.006809
# (1.0, 2.0]       0.002128
# Name: review_scores_rating, dtype: float64

# %% [markdown]
# We know that 93% of all rooms that have at least 1 review in Boston have a rating that ranges from 4 to 5. But we also know that superhost have a minimum score of 4.8 stars.

# %% [markdown]
# Creating specific intervals given that a super host has an overall rating of 4.8+

# %%
rating_bins = pd.IntervalIndex.from_tuples([(0,1), (1,2), (2,3), (3,4), (4,4.8), (4.8,5)])
#taking the numbers on the right side of the interval
rating_bins = rating_bins.right

rating_bins.dtype
# Out:
# dtype('float64')

# %%
pd.cut(ratings, bins=rating_bins).value_counts(normalize=True)
# Out:
# (4.8, 5.0]    0.489717
# (4.0, 4.8]    0.446015
# (3.0, 4.0]    0.050985
# (2.0, 3.0]    0.011140
# (1.0, 2.0]    0.002142
# Name: review_scores_rating, dtype: float64

# %%
fig = plt.figure(figsize=(12,6))
ax = sns.histplot(data=df_raw, x=ratings, stat='percent', bins=rating_bins)
ax.bar_label(ax.containers[-1], fmt="%.2f", label_type='edge', padding=2.5)
ax.set_yticks([])

#array with bins edges that goes in the xticks
ax.set_xticks(rating_bins)
plt.title("Distribution of the Number of Reviews per Score Rating", fontsize=20)
plt.xlabel("Rating Intervals in Stars")
plt.show()

# %% [markdown]
# The histogram above shows us that, from all reviews, 51,1% of them are from superhosts. So, if you are a host and you want more reviews you have got to be a superhost.

# %% [markdown]
# We can see that, on average, apartments on Boston have a 4.7 stars rating. That's fine, but we need to dig a little deeper.
# We can analyse the mean price of apartments based on the quantile that their score_rating lies on.

# %% [markdown]
# ## Price Analysis per Score Rating quantile

# %%
#score rating quantiles
pd.qcut(df_raw.review_scores_rating, q=4).value_counts()
# Out:
# (4.58, 4.8]       604
# (-0.001, 4.58]    603
# (4.8, 4.95]       574
# (4.95, 5.0]       569
# Name: review_scores_rating, dtype: int64

# %% [markdown]
# So the prices are divided in 4 quantiles of score rating. All prices are equally splitted between (0, 4.58], (4.58, 4.8], (4.8, 4.95] and (4.95, 4.5]

# %% [markdown]
# Next we will analyse each score rating quantile with its price distribution using a histogram with trimmed bins and a boxplot covering all bins so we can have a better idea of any outliers that might exist in the prices.

# %% [markdown]
# ### Rooms in the first quantile of Review Score Rating

# %%
quant01_review_df = df_raw[df_raw.review_scores_rating <= 4.58]
pd.qcut(quant01_review_df.price, q=4).value_counts(normalize=True)
# Out:
# (-0.001, 80.0]      0.253731
# (111.0, 157.0]      0.252073
# (80.0, 111.0]       0.247098
# (157.0, 10000.0]    0.247098
# Name: price, dtype: float64

# %%
print(quant01_review_df.price.nlargest())
# Out:
# 1739    10000.0
# 1444     1529.0
# 107      1299.0
# 2223      799.0
# 186       600.0
# Name: price, dtype: float64

# %% [markdown]
# Price range of rooms in the first quantile of review score

# %%
price_bins1 = pd.IntervalIndex.from_breaks(np.arange(0,2100,100))
price_bins1 = price_bins1.right

# %% [markdown]
# We are going to see below, that there is only one outlier after the value of U$2000, so I am going to restrict the range to U$2000 which emcompasses 99% of the rooms with up to 4.58 stars.

# %%
fig = plt.figure(figsize=(12,6))
ax = sns.histplot(data=df_raw, x=quant01_review_df.price, stat='percent', bins=price_bins1)
ax.bar_label(ax.containers[-1], fmt="%.2f", label_type='edge', padding=2.5)

#array with bins edges that goes in the xticks

ax.set_xticks(price_bins1)
plt.title("Price of Rooms with Less than 4.58 stars", fontsize=15)
plt.show()

# %%
fig = plt.figure(figsize=(12,6))
ax = sns.boxplot(x = quant01_review_df.price)
plt.title("Prices of Rooms with up to 4.58 stars", fontsize=20)
plt.show()

# %% [markdown]
# With the boxplot we can have a broader view of the price range. We can see that there's a lot of oulliers and the most expensive room in Boston does not have more than 4.58 stars.

# %% [markdown]
# ### Rooms in the second quantile of Review Score Rating

# %%
quant02_review_df = df_raw.loc[(df_raw.review_scores_rating > 4.58) & (df_raw.review_scores_rating <= 4.80) & (df_raw.price != 0)]
pd.cut(quant02_review_df.price, bins=5).value_counts(normalize=True)
# Out:
# (20.025, 1020.0]    0.996683
# (4005.0, 5000.0]    0.003317
# (1020.0, 2015.0]    0.000000
# (2015.0, 3010.0]    0.000000
# (3010.0, 4005.0]    0.000000
# Name: price, dtype: float64

# %%
print(quant02_review_df.price.nlargest())
# Out:
# 380     5000.0
# 727     5000.0
# 1012     800.0
# 1060     773.0
# 1249     642.0
# Name: price, dtype: float64

# %%
print(quant02_review_df.price.nsmallest())
# Out:
# 51      25.0
# 603     25.0
# 1885    25.0
# 216     27.0
# 314     34.0
# Name: price, dtype: float64

# %%
price_bins2 = pd.IntervalIndex.from_breaks(np.arange(0,1100,100))
price_bins2 = price_bins2.right

# %%
fig = plt.figure(figsize=(12,6))
ax = sns.histplot(data=df_raw, x=quant02_review_df.price, stat='percent', bins=price_bins2)
ax.bar_label(ax.containers[-1], fmt="%.2f", label_type='edge', padding=2.5)

#array with bins edges that goes in the xticks

ax.set_xticks(price_bins2)
plt.title("Price of Rooms with ratings beetween 4.59 and 4.8 stars", fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize=(12,6))
ax = sns.boxplot(x = quant02_review_df.price)
plt.title("Price of Rooms with ratings beetween 4.59 and 4.8", fontsize=20)
plt.show()

# %% [markdown]
# ### Rooms in the third quantile of Review Scores Rating

# %%
quant03_review_df = df_raw.loc[(df_raw.review_scores_rating > 4.8) & (df_raw.review_scores_rating <= 4.95)]
pd.cut(quant03_review_df.price, bins=5).value_counts(normalize=True)
# Out:
# (24.974, 231.2]    0.841463
# (231.2, 436.4]     0.121951
# (436.4, 641.6]     0.024390
# (641.6, 846.8]     0.006969
# (846.8, 1052.0]    0.005226
# Name: price, dtype: float64

# %% [markdown]
# As we have learned, if you're looking for potentials Super Hosts (> 4.8 stars) than you won't find rooms for less than U$231

# %%
price_bins3 = pd.IntervalIndex.from_breaks(np.arange(0,1200,100))
price_bins3 = price_bins3.right

# %%
fig = plt.figure(figsize=(12,6))
ax = sns.histplot(data=df_raw, x=quant03_review_df.price, stat='percent', bins=price_bins3)
ax.bar_label(ax.containers[-1], fmt="%.2f", label_type='edge', padding=2.5)

#array with bins edges that goes in the xticks

ax.set_xticks(price_bins3)
plt.title("Price of Rooms with ratings beetween 4.8 and 4.95 stars", fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize=(12,6))
ax = sns.boxplot(x = quant03_review_df.price)
plt.title("Price of Rooms with ratings beetween 4.8 and 4.95", fontsize=20)
plt.show()

# %% [markdown]
# ### Rooms in the fourth quantile of Review Scores Rating

# %%
quant04_review_df = df_raw.loc[(df_raw.review_scores_rating > 4.95) & (df_raw.review_scores_rating <= 5.0)]
pd.cut(quant04_review_df.price, bins=5).value_counts()
# Out:
# (6.011, 807.8]      560
# (807.8, 1605.6]       7
# (1605.6, 2403.4]      1
# (3201.2, 3999.0]      1
# (2403.4, 3201.2]      0
# Name: price, dtype: int64

# %% [markdown]
# And for the 5 stars rooms, well better save at least U$ 807.8 dollars for just one night

# %%
price_bins4 = pd.IntervalIndex.from_breaks(np.arange(0,1600,100))
price_bins4 = price_bins4.right

# %%
fig = plt.figure(figsize=(12,6))
ax = sns.histplot(data=df_raw, x=quant04_review_df.price, stat='percent', bins=price_bins4)
ax.bar_label(ax.containers[-1], fmt="%.2f", label_type='edge', padding=2.5)

#array with bins edges that goes in the xticks

ax.set_xticks(price_bins4)
plt.title("Price of Rooms with ratings beetween 4.95 and 5 stars", fontsize=20)
plt.show()

# %%
fig = plt.figure(figsize=(12,6))
ax = sns.boxplot(x = quant04_review_df.price)
plt.title("Price of Rooms with ratings beetween 4.95 and 5 stars", fontsize=20)
plt.show()

# %% [markdown]
# ### Average prices per score rating

# %%
#median prices
print(quant01_review_df.price.mean())
print(quant02_review_df.price.mean())
print(quant03_review_df.price.mean())
print(quant04_review_df.price.mean())

#median prices
print(quant01_review_df.price.median())
print(quant02_review_df.price.median())
print(quant03_review_df.price.median())
print(quant04_review_df.price.median())

rating_mean_prices = [quant01_review_df.price.mean(), quant02_review_df.price.mean(), quant03_review_df.price.mean(), quant04_review_df.price.mean()]
rating_median_prices = [quant01_review_df.price.median(), quant02_review_df.price.median(), quant03_review_df.price.median(), quant04_review_df.price.median()]
# Out:
# 154.6301824212272
# 162.0
# 159.14982578397212
# 179.12302284710017
# 111.0
# 125.0
# 125.0
# 124.0

# %% [markdown]
# Comparing all plots

# %%
fig, axes = plt.subplots(2,2, figsize=(60,30))

plt.subplots_adjust(left=0.125,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=0.35)

#defining the histogram bins
price_bins = pd.IntervalIndex.from_breaks(np.arange(-100,1100,100))
price_bins = price_bins.right

#plots and titles
sns.histplot(ax=axes[0,0],  x=quant01_review_df.price, stat='percent', bins=price_bins)
axes[0,0].set_title("Price of Rooms with Less than 4.58 stars", fontsize=60)
sns.histplot(ax=axes[0,1],  x=quant02_review_df.price, stat='percent', bins=price_bins)
axes[0,1].set_title("Price of Rooms between 4.59 and 4.8 stars", fontsize=60)
sns.histplot(ax=axes[1,0],  x=quant03_review_df.price, stat='percent', bins=price_bins)
axes[1,0].set_title("Price of Rooms between 4.8 and 4.95 stars (Superhost)", fontsize=60)
sns.histplot(ax=axes[1,1],  x=quant04_review_df.price, stat='percent', bins=price_bins)
axes[1,1].set_title("Price of Rooms between 4.95 and 5 stars (Superhost)", fontsize=60)

#changing labels
axes[0,0].set_xlabel("")
axes[0,1].set_xlabel("")

# axes[0,0].set_xticks([])
# axes[0,1].set_xticks([])

#annottating on top of the bars and changing xticks
for i in range(0,2):
    for j in range(0,2):
        axes[i,j].bar_label(axes[i,j].containers[-1], fmt="%.2f", label_type='edge', padding=2., fontsize=40)
        axes[i,j].set_ylim(0,80)
        axes[i,j].set_xticks(price_bins)
        axes[i,j].set_yticks([])
        axes[i,j].tick_params(axis='both', which='major', labelsize=40)
        axes[i,j].set_xlabel("Price", fontsize=50)
        axes[i,j].set_ylabel("Percent", fontsize=50)


#annotating the average price on each plot
counter = 0

while counter < len(rating_mean_prices):
    for i in range(0,2):
        for j in range(0,2):
            axes[i,j].annotate(f'Room average price: U${round(rating_mean_prices[counter],0)}',
                        xy=(650,50),verticalalignment='bottom',
                        fontsize=40, bbox=dict(boxstyle="round", fc="yellow"),
                        rotation=0)
            axes[i,j].annotate(f'Room median price: U${round(rating_median_prices[counter],0)}',
                        xy=(650,40),verticalalignment='bottom',
                        fontsize=40, bbox=dict(boxstyle="round", fc="lightgreen"),
                        rotation=0)
            counter+=1



#saving the image
plt.savefig("price_rating.jpg", dpi = 150)

# plt.tight_layout()
# plt.show()

plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\heito\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python310\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# As we can see higher rates, does not necessarily mean higher prices. Of course, there's a small increase in the number of rooms with higher prices as the rating scores go up, but you can be sure that at any score rate interval you'll find that at least 50% of rooms will cost less than U$200 a day.
#
# Another really interesting result is the fact that rooms in which the rating score is between 4.8 and 4.95 are, on average, cheaper than those which rating lies between 4.59 and 4.8.
#
# So if you are looking for high rated room and are concerned with price, in Boston, you can start you search filtering only superhosts, so you can save time.

# %% [markdown]
# ## Rooms by accommodation

# %%
#deleting rooms in which accommodates = 0
print(df_raw[df_raw.accommodates == 0].index)

df_raw = df_raw.drop(index=2175)
# Out:
# Int64Index([2175], dtype='int64')

# %%
#defining the x and y that go into the barplot
x = df_raw.accommodates.value_counts(normalize = True, ascending=False).values
y = df_raw.accommodates.value_counts(ascending=False).index
y.to_numpy()
y = y.astype(str)

# %%
# pd.options.plotting.backend = "plotly"
fig = plt.figure(figsize=(12,6))

#removing chart border
sns.set_context("notebook")
ax = sns.barplot(x=x, y=y)
for spine in plt.gca().spines.values():
    spine.set_visible(False)

#annotating the graph
# for p in ax.patches:
#     ax.annotate(f"{p.get_height()}", (p.get_x() + p.get_width()/2., p.get_height())) 

ax.bar_label(ax.containers[-1], fmt="%.2f", label_type='edge', padding=1.5)
#no xlabel
plt.xlabel("")
#without xticks
plt.xticks([])
plt.title("Distribution of Accommodations", fontsize=20)
plt.ylabel("Number of accommodations")
plt.xlabel("Relative Frequency")
plt.show()

# %% [markdown]
# Most rooms accommodates only 2 people, and if you are looking to travel with the whole family, then your options will drop quite a lot

# %%
pd.qcut(df_raw[df_raw.accommodates == 1].price, q=4).value_counts(normalize=True).round(2)
# Out:
# (-0.001, 37.0]    0.28
# (49.0, 65.0]      0.25
# (65.0, 883.0]     0.24
# (37.0, 49.0]      0.23
# Name: price, dtype: float64

# %%
#how price range with the number od accommodations
ac = df_raw.accommodates.value_counts().index.sort_values()
for i in ac:
    print("Accommodates:", i)
    display(pd.qcut(df_raw[df_raw.accommodates == i].price, q=4).value_counts(normalize=True).round(2))

# %%
# figure = plt.figure(figsize=(12,6))
df_raw_trim = df_raw[df_raw.price <= 2000]
# sns.boxplot(x="accommodates", y="price", data=df_raw_trim)
fig = px.box(
    df_raw_trim, x="accommodates", y="price",
    title = "Distribution of Prices per Accommodation",
    labels = { "price":"Price", "accommodates":"Accommodates"}
    )
fig.update_xaxes(tickangle=0,
                 tickmode = 'array',
                 tickvals = ac)
fig.show()

# %% [markdown]
# The same plot above but now considering only the superhosts

# %%
# sns.boxplot(x="accommodates", y="price", data=df_raw_trim)
fig = px.box(
    super_host_df[super_host_df['price'] <=2000], x="accommodates", y="price",
    title = "Distribution of Prices per Accommodation (Superhosts)",
    labels = { "price":"Price", "accommodates":"Accommodates"}
    )
fig.update_xaxes(tickangle=0,
                 tickmode = 'array',
                 tickvals = ac)
fig.show()

# %% [markdown]
# ## Price Analysis

# %% [markdown]
# I did some string manipulation using Excel, because it was easier and faster than using Python. That is because the price collumn is in a format that is not numeric, so I've just changed the datatype in Excel and updated the df_raw dataset.

# %%
#we can see what are the bins
pd.qcut(df_raw.price, q=4).sort_values().value_counts()
# Out:
# (-0.001, 75.0]      859
# (126.0, 200.0]      841
# (200.0, 10000.0]    832
# (75.0, 126.0]       816
# Name: price, dtype: int64

# %% [markdown]
# With only this result we can see that 3/4 of our data is within the range of $200 bucks. And the last quantile goes from U$200 until U$10000/day. We can confirm that with the following code:

# %%
df_raw.price[df_raw.price <=200].shape[0]/df_raw.shape[0]
# Out:
# 0.7514934289127837

# %% [markdown]
# As we expected, 75% of all apartments have a price up to U$200

# %% [markdown]
# It's very woth mentioning the "qcut" function. This functions is described as a Quantile-based discretization function, so it divides the data into equal-sized bins in which each bins is a quantile (min, 25%, 50% and 75%)

# %% [markdown]
# ### Finding the 10 Most Expensive Rooms in Airbnb Boston

# %%
df_raw.price.nlargest(n=10)
# Out:
# 1739    10000.0
# 380      5000.0
# 727      5000.0
# 576      3999.0
# 1440     2429.0
# 1459     2076.0
# 2306     1995.0
# 1444     1529.0
# 2834     1446.0
# 107      1299.0
# Name: price, dtype: float64

# %% [markdown]
# ### The 10 Cheapest Rooms in Airbnb Boston

# %%
df_raw.price.nsmallest(n=10)
# Out:
# 1845     0.0
# 1870     0.0
# 1871     0.0
# 2139    10.0
# 3321    18.0
# 1784    19.0
# 1767    20.0
# 2918    23.0
# 3303    23.0
# 3028    24.0
# Name: price, dtype: float64

# %% [markdown]
# We have values that are 0, no one rents a room for FREE! At least I don't believe so. That being said, I'll drop these values.

# %%
#dropping rows which price equals 0
price_null = df_raw.price[df_raw.price == 0].index
df_raw.price = df_raw.price.drop(price_null)

# %%
df_raw.price.nsmallest()
# Out:
# 2139    10.0
# 3321    18.0
# 1784    19.0
# 1767    20.0
# 2918    23.0
# Name: price, dtype: float64

# %% [markdown]
# Alright, no more null prices

# %% [markdown]
# ## Analysing Super Hosts' Rooms Prices

# %%
# defyning a function to create the csv files from the data

def create_csv(index, df, str):

    urls = []
    prices = []
    ratings = []
    values = []
    accommodates = []
    num_reviews = []

    for i in index:
        print(f"Room Price: U${df.loc[i].price}\nRoom URL: {df.loc[i].listing_url}\nOverall Rating: {df.loc[i].review_scores_rating}\nAccommodates: {df.loc[i].accommodates}\nOverall Value: {df.loc[i].review_scores_value}\nNumber of Reviews: {df.loc[i].number_of_reviews}\n")
        #appending these values to a list
        prices.append(df.loc[i].price)
        urls.append(df.loc[i].listing_url)
        ratings.append(df.loc[i].review_scores_rating)
        accommodates.append(df.loc[i].accommodates)
        values.append(df.loc[i].review_scores_value)
        num_reviews.append(df.loc[i].number_of_reviews)

    data = [prices, accommodates, ratings, values, num_reviews, urls]
    columns = ["Price", "Accommodates", "Overall Rating", "Value", "Reviews", "url"]
    final_df = pd.DataFrame.from_records(data).transpose()
    final_df.columns = columns
    final_df.set_index("url", inplace=True)
    
    #exporting the dataframe to a csv file
    final_df.to_csv(str, sep=",")

# %% [markdown]
# ### Price Range

# %%
pd.qcut(super_host_df.price, q=4).value_counts()
# Out:
# (-0.001, 54.0]     257
# (106.0, 175.0]     257
# (54.0, 106.0]      250
# (175.0, 1104.0]    245
# Name: price, dtype: int64

# %% [markdown]
# We can see that 75% of all rooms hosted by superhosts in Boston have a price ranging from U$10 to U$175.
# So, knowing that, I'll break this analysis down into the following parts:
# * The 5 cheapest rooms
# * The 5 most expensive rooms
# * The best values rooms if your staying alone
# * The best values rooms for couples
# * The best values rooms for families (up to 5 people)

# %% [markdown]
# As we go through this analysis there are going to be some rooms which might not be available by the time you are reading this or which prices are not updated. But, anyway, it can give us a nice overview about the rooms in Boston

# %% [markdown]
# ### Lowest Prices

# %%
super_host_df.price.nsmallest()
# Out:
# id
# 46232976     0.0
# 45828592    10.0
# 51816556    23.0
# 52532097    24.0
# 29711943    25.0
# Name: price, dtype: float64

# %%
## creating a list to storage the five cheapest super hosted rooms in Boston
cheapest_sh = super_host_df.price[(super_host_df.price != 0.) & (super_host_df.review_scores_rating.notnull()) & (super_host_df.review_scores_value.notnull())].nsmallest(10).index
cheapest_sh
# Out:
# Int64Index([45828592, 29711943,  4755586, 35547817, 23375776, 12336281,
#             13258244, 23842606, 49941156, 10524872],
#            dtype='int64', name='id')

# %% [markdown]
# I am going to filter not only the cheapest rooms but also those that have at least one review and some score and value rating

# %%
for i in cheapest_sh:
        print(f"Room Price: U${super_host_df.loc[i].price}\nRoom URL: {super_host_df.loc[i].listing_url}\nOverall Rating: {super_host_df.loc[i].review_scores_rating}\nAccommodates: {super_host_df.loc[i].accommodates}\nOverall Value: {super_host_df.loc[i].review_scores_value}\nNumber of Reviews: {super_host_df.loc[i].number_of_reviews}\n")

#exporting to a csv file
create_csv(cheapest_sh, super_host_df, "cheapest_rooms.csv")

# %% [markdown]
# #### Best Rooms for families (up to 5 people)

# %%
#taking a subset of the df where accommodates=4 and the host is a superhost
for_4_sh = df_raw.loc[(df_raw.accommodates == 5) & (df_raw.host_is_superhost == 't')]

# %%
#cheapest superhosted rooms that accommodates 5 people
cheapest_sh_for_5 = for_4_sh[for_4_sh.review_scores_rating == 5.0].price.nsmallest(5).index

# %%
for i in cheapest_sh_for_5:
        print(f"Room Price: U${for_4_sh.loc[i].price}\nRoom URL: {for_4_sh.loc[i].listing_url}\nOverall Rating: {for_4_sh.loc[i].review_scores_rating}\nNumber of Reviews: {for_4_sh.loc[i].number_of_reviews}\nOverall Value: {for_4_sh.loc[i].review_scores_value}\n ")

#exporting to a csv
create_csv(cheapest_sh_for_5, for_4_sh, "best_sh_for_five.csv")
# Out:
# Room Price: U$53.0
# Room URL: https://www.airbnb.com/rooms/42364097
# Overall Rating: 5.0
# Number of Reviews: 1
# Overall Value: 5.0
#
# Room Price: U$60.0
# Room URL: https://www.airbnb.com/rooms/52264392
# Overall Rating: 5.0
# Number of Reviews: 14
# Overall Value: 5.0
#
# Room Price: U$175.0
# Room URL: https://www.airbnb.com/rooms/33552900
# Overall Rating: 5.0
# Number of Reviews: 26
# Overall Value: 4.85
#
# Room Price: U$183.0
# Room URL: https://www.airbnb.com/rooms/53115783
# Overall Rating: 5.0
# Number of Reviews: 1
# Overall Value: 5.0
#
# Room Price: U$200.0
# Room URL: https://www.airbnb.com/rooms/41763645
# Overall Rating: 5.0
# Number of Reviews: 4
# Overall Value: 5.0
#
# Room Price: U$53.0
# Room URL: https://www.airbnb.com/rooms/42364097
# Overall Rating: 5.0
# Accommodates: 5
# Overall Value: 5.0
# Number of Reviews: 1
#
# Room Price: U$60.0
# Room URL: https://www.airbnb.com/rooms/52264392
# Overall Rating: 5.0
# Accommodates: 5
# Overall Value: 5.0
# ...

# %% [markdown]
# Well, the room that costs only U$53 a day, remains with its price unaltered by the time I'm writing this (26/2/2022) and it looks really nice. It seems to be the best option for families in Boston when considering price and value.

# %% [markdown]
# ### Highest Prices

# %%
highest_prices_sh = super_host_df.price.nlargest().index
highest_prices_sh
# Out:
# Int64Index([7618925, 20650593, 45531759, 48001583, 24484501], dtype='int64', name='id')

# %%
for i in highest_prices_sh:
        print(f"Room Price: U${super_host_df.loc[i].price}\nRoom URL: {super_host_df.loc[i].listing_url}\nOverall Rating: {super_host_df.loc[i].review_scores_rating}\nAccommodates: {super_host_df.loc[i].accommodates}\nOverall Value: {super_host_df.loc[i].review_scores_value}\nNumber of Reviews: {super_host_df.loc[i].number_of_reviews}\n ")

#creating a csv with that data
create_csv(highest_prices_sh, super_host_df, "most_expensive.csv")

# %% [markdown]
# #### Cheapest Rooms if you are staying alone

# %% [markdown]
# Here, once again I am not considering those rooms with not ratings or score values

# %%
#taking a subset of the df where accommodates=1 and the host is a superhost
for_1_sh = df_raw.loc[(df_raw.accommodates == 1) & (df_raw.host_is_superhost == 't') & (df_raw.review_scores_rating.notnull()) & (df_raw.review_scores_value.notnull())]
best_for_one = for_1_sh.price.nsmallest().index

# %%
print("Cheapest Rooms for one person\n")

for i in best_for_one:
        print(f"Room Price: U${for_1_sh.loc[i].price}\nRoom URL: {for_1_sh.loc[i].listing_url}\nOverall Rating: {for_1_sh.loc[i].review_scores_rating}\nNumber of Reviews: {for_1_sh.loc[i].number_of_reviews}\nOverall Value: {for_1_sh.loc[i].review_scores_value}\nAccommodates: {for_1_sh.loc[i].accommodates}\n")

#expoting to a csv file
create_csv(best_for_one, for_1_sh,"cheapest_sh_for_one.csv")

# %% [markdown]
# #### Cheapest Rooms for Couples

# %%
for_2_sh = df_raw.loc[(df_raw.accommodates == 2) & (df_raw.host_is_superhost == 't') & (df_raw.review_scores_rating.notnull()) & (df_raw.review_scores_value.notnull())]
best_for_two = for_2_sh.price.nsmallest().index

# %%
for i in best_for_two:
        print(f"Room Price: U${for_2_sh.loc[i].price}\nRoom URL: {for_2_sh.loc[i].listing_url}\nOverall Rating: {for_2_sh.loc[i].review_scores_rating}\nNumber of Reviews: {for_2_sh.loc[i].number_of_reviews}\nOverall Value: {for_2_sh.loc[i].review_scores_value}\nAccommodates: {for_2_sh.loc[i].accommodates}\n ")

#exporting to a csv
create_csv(best_for_two, for_2_sh, "cheapest_sh_for_two.csv")

# %% [markdown]
# #### Price of the rooms with the highest number of reviews

# %% [markdown]
# Once again, be aware that the number of reviews are not up to date values, since it's been four years since the data was scraped. Anyway, the analysis does not lose its value given that the tendency is that the number of reviews will have increased.

# %%
highest_reviews = df_raw.number_of_reviews.nlargest().index
highest_reviews
# Out:
# Int64Index([172, 56, 63, 781, 105], dtype='int64')

# %%
for i in highest_reviews:
    print(f"Number of Reviews: {df_raw.loc[i].number_of_reviews}\nRoom Price: U$ {df_raw.loc[i].price}\nRoom URL: {df_raw.loc[i].listing_url}\nOverall Rating: {df_raw.loc[i].review_scores_rating}\nAccommodates: {df_raw.loc[i].accommodates}\nOverall Value: {df_raw.loc[i].review_scores_value}\n")

#exporting to a csv
create_csv(highest_reviews, df_raw, "highest_reviews.csv")

# %% [markdown]
# This simple analysis showed us a quite interesting result. The fourth most reviewed room is also very cheap, just U$54/day and with the second highest overall rating between the most reviewed

# %% [markdown]
# # Conclusion <a class="anchor" id="5"></a>

# %% [markdown]
# I've posted an article on Medum with the main insights draw from it.
# Check it out, here!

# %% [markdown]
# ## Amenities (An idea for a future project)

# %% [markdown]
# ### Machine Learning Model

# %%
import json
#defining a function that returns all amenities in the dataset
def unique_amenities():

    unique = []
    for l in df_raw.amenities:
        #converting the string representation of a list to a list
        l = json.loads(l)
        # print(l)
        for amenitie in l:
            if amenitie not in unique:
                unique.append(amenitie)
    
    return unique

len(unique_amenities())
# Out:
# 557

# %% [markdown]
# We can conclude, therefore that there are 557 different amenities in our dataset. But if we take a closer look to it, we will see that many of them are different amenities that represent the same thing, such as different types of T.V

# %% [markdown]
# What would be nice to know is what amenities are responsible for a higher room price. But, to do so, we need first to convert our categorical data into a binary form.
